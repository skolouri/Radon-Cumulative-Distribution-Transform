# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from skimage.io import imread
from scipy.ndimage import filters
from sklearn.svm import LinearSVC
from matplotlib import colors
from skimage.color import rgb2gray

import transportBasedTransforms.radonCDT as RCDT

# %matplotlib inline

# %%
I=[]
I.append(rgb2gray(imread('./Data/I0.bmp')))
I.append(rgb2gray(imread('./Data/I1.bmp')))
I0=np.ones_like(I[0])

# %%
fig,ax=plt.subplots(1,2,figsize=(10,5))
for i in range(2):
    ax[i].imshow(I[i])
plt.show()

# %%
rcdt=RCDT.RadonCDT(template=I0)

# %%
Ihat=[]
fig,ax=plt.subplots(1,2,figsize=(10,5))
for i in range(2):
    Ihat.append(rcdt.transform(I[i]))
    ax[i].imshow(Ihat[i])
plt.show()

# %%
plt.imshow(rcdt.itransform(Ihat[i]))
plt.show()
# Out:
# transportBasedTransforms/cdt.py:48: RuntimeWarning: invalid value encountered in divide
#   u=Ihat/np.sqrt(self.template)
# /Users/skolouri/Documents/VirtualEnv2/lib/python2.7/site-packages/skimage/transform/radon_transform.py:204: UserWarning: The default of `circle` in `skimage.transform.iradon` will change to `True` in version 0.15.
#   warn('The default of `circle` in `skimage.transform.iradon` '
# /Users/skolouri/Documents/VirtualEnv2/lib/python2.7/site-packages/matplotlib/colors.py:823: UserWarning: Warning: converting a masked element to nan.
#   dtype = np.min_scalar_type(value)
# /Users/skolouri/Documents/VirtualEnv2/lib/python2.7/site-packages/numpy/ma/core.py:2809: UserWarning: Warning: converting a masked element to nan.
#   order=order, subok=True, ndmin=ndmin)

# %%
Itilde=rcdt.itransform(Ihat[i])

# %%
Itilde.shape
# Out:
# (480, 480)

# %%
plt.imshow(Itilde)
plt.show()

# %%
(1.*np.isnan(Itilde)).sum()
# Out:
# 230400.0
